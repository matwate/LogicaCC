# %%
from Queens import *
from tree_less_logic import *
super_important_function_that_every_project_needs()
# Out:
#   ／l、
# （ﾟ､ ｡ ７
#   l  ~ヽ
#   じしf_,)ノ

# %%
reinas = Reinas(8)
desc = reinas.Reina_En_Casilla
# Out:
# Building regla4...

# %%
# %%time

itt1 = inorder_to_tree(reinas.r1)
itt2 = inorder_to_tree(reinas.r2)
itt3 = inorder_to_tree(reinas.r3)
with open('itt1.txt', 'w', encoding="utf-8") as f:    
    f.write(str(tseitin(Ytoria([reinas.r1, reinas.r2, reinas.r3, reinas.r4]))))
# Out:
# CPU times: user 243 ms, sys: 6.62 ms, total: 250 ms
# Wall time: 248 ms

# %%
# %%time

rpn1 = to_reverse_polish(reinas.r1)
rpn2 = to_reverse_polish(reinas.r2)
rpn3 = to_reverse_polish(reinas.r3)
# Out:
# CPU times: user 1.52 ms, sys: 0 ns, total: 1.52 ms
# Wall time: 1.55 ms

# %%
# %%time

rpn4 = to_reverse_polish(reinas.r4)
# Out:
# CPU times: user 90 μs, sys: 0 ns, total: 90 μs
# Wall time: 92.7 μs

# %%
#itt4 = inorder_to_tree(reinas.r4)
print("Inorder to tree won't finish for r4")
# Out:
# Inorder to tree won't finish for r4

# %%
# %%time 
all_rules = [reinas.r1, reinas.r2, reinas.r3,reinas.r4]
todas = reduce(lambda x,y: f"({x}Y{y})", all_rules)
# Out:
# CPU times: user 23 μs, sys: 1 μs, total: 24 μs
# Wall time: 43.6 μs

# %%
# %%time
rpn5 = to_reverse_polish(todas)
# Out:
# CPU times: user 3.91 ms, sys: 46 μs, total: 3.95 ms
# Wall time: 3.45 ms

# %%
# %%time
#itt5 = inorder_to_tree(todas)
print("You really thought it was going to finish?")
# Out:
# You really thought it was going to finish?
# CPU times: user 72 μs, sys: 6 μs, total: 78 μs
# Wall time: 320 μs

# %% [markdown]
# ## Individual SAT

# %%
# %%time
r1_ws = WalkSat(reinas.r1, 10, 465, 0.01)
sat , inter = r1_ws.SAT_till_SAT()
if sat != "IDK YET":
    reinas.visualizar(inter)
else:
    print(sat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:634, in WalkSat.SAT_till_SAT(self)
#     633 def SAT_till_SAT(self):
# --> 634     sat, inter = self.SAT()
#     635     walk_sat_attempts = 1
#     636     while sat != "SAT":
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:630, in WalkSat.SAT(self)
#     628 sat = ""
#     629 for _ in range(self.max_tries):
# --> 630     sat = self.try_()
#     631 return sat
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:579, in WalkSat.try_(self)
#     577     return "SAT", self.model
#     578 for _ in range(self.max_flips):
# --> 579     lit = self.least_break_force()
#     580     will_it_flip = random.uniform(0, 1)
#     581     if will_it_flip > self.temp:
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:606, in WalkSat.least_break_force(self)
# ...

# %%
# %%time
r1_ws = WalkSat(reinas.r2, 10, 465, 0.01)
sat , inter = r1_ws.SAT_till_SAT()
if sat != "IDK YET":
    reinas.visualizar(inter)
else:
    print(sat)
# Out:
#  Hay una reina en la casilla (2,0)
#  Hay una reina en la casilla (1,1)
#  Hay una reina en la casilla (3,2)
#  Hay una reina en la casilla (2,3)
# CPU times: user 34.4 s, sys: 6.66 ms, total: 34.4 s
# Wall time: 34.5 s

# %%
# %%time
r1_ws = WalkSat(reinas.r3, 10, 465, 0.01)
sat , inter = r1_ws.SAT_till_SAT()
if sat != "IDK YET":
    reinas.visualizar(inter)
else:
    print(sat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:634, in WalkSat.SAT_till_SAT(self)
#     633 def SAT_till_SAT(self):
# --> 634     sat, inter = self.SAT()
#     635     walk_sat_attempts = 1
#     636     while sat != "SAT":
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:630, in WalkSat.SAT(self)
#     628 sat = ""
#     629 for _ in range(self.max_tries):
# --> 630     sat = self.try_()
#     631 return sat
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:579, in WalkSat.try_(self)
#     577     return "SAT", self.model
#     578 for _ in range(self.max_flips):
# --> 579     lit = self.least_break_force()
#     580     will_it_flip = random.randrange(0, 1)
#     581     if will_it_flip > self.temp:
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:606, in WalkSat.least_break_force(self)
# ...

# %%
# %%time
r1_ws = WalkSat(reinas.r4, 10, 465, 0.01)
sat , inter = r1_ws.SAT_till_SAT()
if sat != "IDK YET":
    reinas.visualizar(inter)
else:
    print(sat)
# Out:
# It took 1 attempts to find a SAT model
#  Hay una reina en la casilla (0,0)
#  Hay una reina en la casilla (1,0)
#  Hay una reina en la casilla (2,0)
#  Hay una reina en la casilla (1,1)
#  Hay una reina en la casilla (2,1)
#  Hay una reina en la casilla (3,1)
#  Hay una reina en la casilla (1,2)
#  Hay una reina en la casilla (3,2)
#  Hay una reina en la casilla (0,3)
#  Hay una reina en la casilla (1,3)
#  Hay una reina en la casilla (3,3)
# CPU times: user 53.7 ms, sys: 0 ns, total: 53.7 ms
# Wall time: 53 ms

# %% [markdown]
# ## Full SAT

# %%
# %%time
r1_ws = WalkSat(todas, 10, 465, 0.01)
sat , inter = r1_ws.SAT_till_SAT()
if sat != "IDK YET":
    reinas.visualizar(inter)
else:
    print(sat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:634, in WalkSat.SAT_till_SAT(self)
#     632 while sat != "SAT":
#     633     walk_sat_attempts += 1
# --> 634     sat, inter = self.SAT()
#     635 print(f"It took {walk_sat_attempts} attempts to find a SAT model")
#     636 return sat, inter
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:626, in WalkSat.SAT(self)
#     624 sat = ""
#     625 for _ in range(self.max_tries):
# --> 626     sat = self.try_()
#     627 return sat
#
# File ~/Desktop/Code/LogicaCC/tree_less_logic.py:579, in WalkSat.try_(self)
#     577     return "SAT", self.model
#     578 for _ in range(self.max_flips):
# --> 579     lit = self.least_break_force()
#     580     will_it_flip = random.randrange(0, 1)
#     581     if will_it_flip > self.temp:
#
# ...
